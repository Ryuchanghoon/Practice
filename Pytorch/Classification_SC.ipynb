# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.linear_model import SGDClassifier


import numpy as np
import pandas as pd

# %% [markdown]
# ### baseline ==> 92.56(accuracy)

# %%
label1 = pd.read_csv('/content/drive/MyDrive/GDSC_AI/Solution Challenge/label_waist_1')
label0 = pd.read_csv('/content/drive/MyDrive/GDSC_AI/Solution Challenge/label_waist_wrong_0')

# %%
label1.head()
# Out:
#    Unnamed: 0  right_hip_x  right_hip_y  left_hip_x  left_hip_y  right_knee_x  \
# 0           0     0.453636     0.899492    0.469188    0.846481      0.602368
# 1           1     0.449044     0.884647    0.465157    0.835519      0.607273
# 2           2     0.444132     0.879613    0.460910    0.825427      0.608939
# 3           3     0.448101     0.882722    0.468768    0.824901      0.609450
# 4           4     0.449228     0.883968    0.470320    0.824633      0.607503
#
#    right_knee_y  left_knee_x  left_knee_y  left_shoulder_x  left_shoulder_y  \
# 0      0.962444     0.576653     0.835767         0.437108         0.532054
# 1      0.945549     0.577152     0.813978         0.428670         0.532539
# 2      0.946792     0.575827     0.811927         0.424906         0.532780
# 3      0.947762     0.583055     0.818395         0.431174         0.532957
# 4      0.944532     0.585183     0.826263         0.429919         0.532688
#
# ...

# %%
sum_label = pd.concat([label1, label0], axis = 0, ignore_index = True)

# %%
sum_label.head()
# Out:
#    Unnamed: 0  right_hip_x  right_hip_y  left_hip_x  left_hip_y  right_knee_x  \
# 0           0     0.453636     0.899492    0.469188    0.846481      0.602368
# 1           1     0.449044     0.884647    0.465157    0.835519      0.607273
# 2           2     0.444132     0.879613    0.460910    0.825427      0.608939
# 3           3     0.448101     0.882722    0.468768    0.824901      0.609450
# 4           4     0.449228     0.883968    0.470320    0.824633      0.607503
#
#    right_knee_y  left_knee_x  left_knee_y  left_shoulder_x  left_shoulder_y  \
# 0      0.962444     0.576653     0.835767         0.437108         0.532054
# 1      0.945549     0.577152     0.813978         0.428670         0.532539
# 2      0.946792     0.575827     0.811927         0.424906         0.532780
# 3      0.947762     0.583055     0.818395         0.431174         0.532957
# 4      0.944532     0.585183     0.826263         0.429919         0.532688
#
# ...

# %%
sum_label
# Out:
#       Unnamed: 0  right_hip_x  right_hip_y  left_hip_x  left_hip_y  \
# 0              0     0.453636     0.899492    0.469188    0.846481
# 1              1     0.449044     0.884647    0.465157    0.835519
# 2              2     0.444132     0.879613    0.460910    0.825427
# 3              3     0.448101     0.882722    0.468768    0.824901
# 4              4     0.449228     0.883968    0.470320    0.824633
# ...          ...          ...          ...         ...         ...
# 2763        1568     0.493023     0.607644    0.492830    0.595055
# 2764        1569     0.493600     0.607868    0.492858    0.598215
# 2765        1570     0.494066     0.607785    0.493623    0.597199
# 2766        1571     0.494598     0.607757    0.494479    0.596993
# 2767        1572     0.495236     0.607710    0.495795    0.596473
#
#       right_knee_x  right_knee_y  left_knee_x  left_knee_y  left_shoulder_x  \
# 0         0.602368      0.962444     0.576653     0.835767         0.437108
# ...

# %%
sum_label.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2768 entries, 0 to 2767
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        2768 non-null   int64
#  1   right_hip_x       2768 non-null   float64
#  2   right_hip_y       2768 non-null   float64
#  3   left_hip_x        2768 non-null   float64
#  4   left_hip_y        2768 non-null   float64
#  5   right_knee_x      2768 non-null   float64
#  6   right_knee_y      2768 non-null   float64
#  7   left_knee_x       2768 non-null   float64
#  8   left_knee_y       2768 non-null   float64
#  9   left_shoulder_x   2768 non-null   float64
#  10  left_shoulder_y   2768 non-null   float64
#  11  right_shoulder_x  2768 non-null   float64
#  12  right_shoulder_y  2768 non-null   float64
#  13  target            2768 non-null   int64
# dtypes: float64(12), int64(2)
# memory usage: 302.9 KB

# %%
sum_label = sum_label.drop(columns = 'Unnamed: 0')
sum_label.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2768 entries, 0 to 2767
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   right_hip_x       2768 non-null   float64
#  1   right_hip_y       2768 non-null   float64
#  2   left_hip_x        2768 non-null   float64
#  3   left_hip_y        2768 non-null   float64
#  4   right_knee_x      2768 non-null   float64
#  5   right_knee_y      2768 non-null   float64
#  6   left_knee_x       2768 non-null   float64
#  7   left_knee_y       2768 non-null   float64
#  8   left_shoulder_x   2768 non-null   float64
#  9   left_shoulder_y   2768 non-null   float64
#  10  right_shoulder_x  2768 non-null   float64
#  11  right_shoulder_y  2768 non-null   float64
#  12  target            2768 non-null   int64
# dtypes: float64(12), int64(1)
# memory usage: 281.2 KB

# %%
X = sum_label.drop(columns = 'target')
y = sum_label['target']

# %%
print(X.info())

print('\n')

print(y.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2768 entries, 0 to 2767
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   right_hip_x       2768 non-null   float64
#  1   right_hip_y       2768 non-null   float64
#  2   left_hip_x        2768 non-null   float64
#  3   left_hip_y        2768 non-null   float64
#  4   right_knee_x      2768 non-null   float64
#  5   right_knee_y      2768 non-null   float64
#  6   left_knee_x       2768 non-null   float64
#  7   left_knee_y       2768 non-null   float64
#  8   left_shoulder_x   2768 non-null   float64
#  9   left_shoulder_y   2768 non-null   float64
#  10  right_shoulder_x  2768 non-null   float64
#  11  right_shoulder_y  2768 non-null   float64
# dtypes: float64(12)
# memory usage: 259.6 KB
# None
#
#
# <class 'pandas.core.series.Series'>
# RangeIndex: 2768 entries, 0 to 2767
# Series name: target
# Non-Null Count  Dtype
# --------------  -----
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
sc = StandardScaler()
sc.fit(X_train)
X_train_std = sc.transform(X_train)
X_test_std = sc.transform(X_test)

# %%
### LogisticRegression

model = LogisticRegression()
model.fit(X_train_std, y_train)
# Out:
# LogisticRegression()

# %%
#### SGDClassifier

SGDC = SGDClassifier(max_iter=10000) # 디폴트 값 1000

SGDC.fit(X_train_std, y_train)


y_pred_sgd = SGDC.predict(X_test_std)

accuracy = accuracy_score(y_test, y_pred_sgd)

print(accuracy)
# Out:
# 0.9434416365824309

# %%
#### DecisionTreeClassifier

from sklearn.tree import DecisionTreeClassifier

DTC = DecisionTreeClassifier(max_depth = 7, random_state = 3)

DTC.fit(X_train_std, y_train)

y_pred_dtc = DTC.predict(X_test_std)

accuracy = accuracy_score(y_test, y_pred_dtc)

print(accuracy)
# Out:
# 0.9831528279181708

# %%
### RandomForestClassifier

from sklearn.ensemble import RandomForestClassifier

RFC = RandomForestClassifier(n_estimators = 1000, random_state = 42) # n_estimators ==> 트리 개수

RFC.fit(X_train_std, y_train)

y_pred_rfc = RFC.predict(X_test_std)

accuracy = accuracy_score(y_test, y_pred_rfc)

print(accuracy)
# Out:
# 0.9891696750902527

# %%
### SVM

from sklearn import svm


SVM = svm.SVC(kernel = 'poly', random_state = 5)

SVM.fit(X_train_std, y_train)

y_pred_svm = SVM.predict(X_test_std)

accuracy = accuracy_score(y_test, y_pred_svm)

print(accuracy)
# Out:
# 0.9614921780986763

# %%
y_pred = model.predict(X_test_std)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: {:.2f}".format(accuracy))
# Out:
# Accuracy: 0.93
