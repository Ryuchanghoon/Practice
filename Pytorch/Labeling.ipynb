# %%
import pandas as pd
import numpy as np
import csv

# %%
label1 = pd.read_csv('/content/drive/MyDrive/GDSC_AI/Solution Challenge/waist.csv')
label0 = pd.read_csv('/content/drive/MyDrive/GDSC_AI/Solution Challenge/waist_wrong.csv')

# %%
label1['target'] = 1

# %%
label1.head()
# Out:
#    right_hip_x  right_hip_y  left_hip_x  left_hip_y  right_knee_x  \
# 0     0.453636     0.899492    0.469188    0.846481      0.602368
# 1     0.449044     0.884647    0.465157    0.835519      0.607273
# 2     0.444132     0.879613    0.460910    0.825427      0.608939
# 3     0.448101     0.882722    0.468768    0.824901      0.609450
# 4     0.449228     0.883968    0.470320    0.824633      0.607503
#
#    right_knee_y  left_knee_x  left_knee_y  left_shoulder_x  left_shoulder_y  \
# 0      0.962444     0.576653     0.835767         0.437108         0.532054
# 1      0.945549     0.577152     0.813978         0.428670         0.532539
# 2      0.946792     0.575827     0.811927         0.424906         0.532780
# 3      0.947762     0.583055     0.818395         0.431174         0.532957
# 4      0.944532     0.585183     0.826263         0.429919         0.532688
#
#    right_shoulder_x  right_shoulder_y  target
# 0          0.425006          0.563828       1
# ...

# %%
label0['target'] = 0

# %%
label0.head()
# Out:
#    right_hip_x  right_hip_y  left_hip_x  left_hip_y  right_knee_x  \
# 0     0.458738     0.849062    0.536371    0.848492      0.396225
# 1     0.450247     0.832411    0.537374    0.832439      0.403935
# 2     0.448319     0.832718    0.538049    0.835151      0.393437
# 3     0.447552     0.835649    0.539801    0.838632      0.396486
# 4     0.447542     0.834528    0.539954    0.838084      0.395822
#
#    right_knee_y  left_knee_x  left_knee_y  left_shoulder_x  left_shoulder_y  \
# 0      1.068137     0.574903     1.085110         0.563376         0.520082
# 1      1.072072     0.590602     1.024097         0.568154         0.512963
# 2      1.040495     0.585966     1.050283         0.568724         0.511885
# 3      1.066639     0.586378     1.055725         0.570970         0.512662
# 4      1.062869     0.588211     1.052322         0.569185         0.511730
#
#    right_shoulder_x  right_shoulder_y  target
# 0          0.434417          0.514061       0
# ...

# %%
label1.to_csv('label_waist_1')

# %%
pd.read_csv('/content/label_waist_1')
# Out:
#       Unnamed: 0  right_hip_x  right_hip_y  left_hip_x  left_hip_y  \
# 0              0     0.453636     0.899492    0.469188    0.846481
# 1              1     0.449044     0.884647    0.465157    0.835519
# 2              2     0.444132     0.879613    0.460910    0.825427
# 3              3     0.448101     0.882722    0.468768    0.824901
# 4              4     0.449228     0.883968    0.470320    0.824633
# ...          ...          ...          ...         ...         ...
# 1190        1190     0.525483     0.966817    0.511627    0.942689
# 1191        1191     0.527643     0.968608    0.511155    0.943362
# 1192        1192     0.533262     0.970773    0.511532    0.946156
# 1193        1193     0.532556     0.972935    0.512378    0.949536
# 1194        1194     0.532166     0.974915    0.517551    0.951269
#
#       right_knee_x  right_knee_y  left_knee_x  left_knee_y  left_shoulder_x  \
# 0         0.602368      0.962444     0.576653     0.835767         0.437108
# ...

# %%
label0.to_csv('waist_wrong_0')

# %%
label0 = pd.read_csv('/content/waist_wrong_0')

label0.head()
# Out:
#    Unnamed: 0  right_hip_x  right_hip_y  left_hip_x  left_hip_y  right_knee_x  \
# 0           0     0.458738     0.849062    0.536371    0.848492      0.396225
# 1           1     0.450247     0.832411    0.537374    0.832439      0.403935
# 2           2     0.448319     0.832718    0.538049    0.835151      0.393437
# 3           3     0.447552     0.835649    0.539801    0.838632      0.396486
# 4           4     0.447542     0.834528    0.539954    0.838084      0.395822
#
#    right_knee_y  left_knee_x  left_knee_y  left_shoulder_x  left_shoulder_y  \
# 0      1.068137     0.574903     1.085110         0.563376         0.520082
# 1      1.072072     0.590602     1.024097         0.568154         0.512963
# 2      1.040495     0.585966     1.050283         0.568724         0.511885
# 3      1.066639     0.586378     1.055725         0.570970         0.512662
# 4      1.062869     0.588211     1.052322         0.569185         0.511730
#
# ...
